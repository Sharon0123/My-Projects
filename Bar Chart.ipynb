# %% [markdown]
# <h1 id="types_objects" align="center">Sharon Raja S</h1>

# %% [markdown]
# <h2 id="types_objects" align="center">My Project 4</h2>

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style

# %% [markdown]
# <h2 id="types_objects" align="center">Bar Chart</h2>
# <h3 id="types_objects" align="center">Bar Chart using a list or a table (Vertical)</h3>

# %%
x=['A','B','C','D']
y=[10,30,20,40]

plt.bar(x,y)
plt.show()

# %%
x=np.arange(0,10)
y=x+1

plt.bar(x,y)
plt.show()

# %% [markdown]
# ### bar chart using numpy

# %%
xpts=np.array([0,4])
ypts=np.array([0,100])

plt.bar(xpts,ypts)
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[10,50,100,80,60,90]

plt.bar(x,y)
plt.show()

# %% [markdown]
# #### line color

# %%
plt.bar(x,y,color="green")
plt.show()

# %% [markdown]
# #### bar width

# %%
plt.bar(x,y,color="b",width=0.4)
plt.show()

# %% [markdown]
# ### yearly placements

# %%
x=['2019','2020','2021','2022','2023']
y=[256,305,418,354,276,]

# %%
plt.bar(x,y,color='y')
plt.xlabel('Year')
plt.ylabel('Placements')
plt.show()

# %% [markdown]
# ### average time spend on social media

# %%
time_data={'facebook':120,'youtube':90,'instagram':40,'snapchat':28}
social_media=list(time_data.keys())
time_spend=list(time_data.values())

style.use('ggplot')
plt.figure(figsize=(5,5))
plt.bar(social_media,time_spend,color='purple',width=0.5)
plt.title('Average time spend on social media')
plt.xlabel('Social Media')
plt.ylabel('Time in Minutes')
plt.show()

# %% [markdown]
# ### multiple bar chart

# %%
fb=(120,90,110,100,95)
yt=(80,90,75,85,95)
ig=(50,40,55,35,45)
sc=(20,30,35,25,28)
xpos=np.arange(len(fb))

# %%
style.use('ggplot')
plt.figure(figsize=(10,7))
barwidth=0.2
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos+0.2,yt,color='red',width=barwidth,label='YT')
plt.bar(xpos+0.4,ig,color='purple',width=barwidth,label='IG')
plt.bar(xpos+0.6,sc,color='y',width=barwidth,label='SC')
plt.xticks(xpos+0.3,('Monday','Tuesday','Wednesday','Thursday','Friday'))
plt.title('Time spend on Social Media')
plt.xlabel('Day')
plt.ylabel('Time spend in minutes')
plt.legend()
plt.show()

# %% [markdown]
# ### stacked bar chart

# %%
fb=(120,90,110,100,95)
yt=(80,90,75,85,95)
ig=(50,40,55,35,45)
sc=(20,30,35,25,28)
x=['Monday','Tuesday','Wednesday','Thursday','Friday']
xpos=np.arange(len(x))
barwidth=0.4

plt.figure(figsize=(10,7))
plt.bar(xpos,fb,color='royalblue',width=barwidth,label='FB')
plt.bar(xpos,yt,bottom=fb,color='red',width=barwidth,label='YT')
plt.bar(xpos,ig,bottom=yt,color='purple',width=barwidth,label='IG')
plt.bar(xpos,sc,bottom=fb,color='y',width=barwidth,label='SC')


plt.title('Time spend on Social Media')
plt.xlabel('Day')
plt.ylabel('Time spend in minutes')
plt.legend()
plt.xticks(xpos,x)
plt.show()

# %% [markdown]
# <h3 id="types_objects" align="center">Horizontal Bar Chart using a list or a table</h3>

# %%
x=['A','B','C','D']
y=[10,30,20,40]

plt.barh(x,y)
plt.show()
