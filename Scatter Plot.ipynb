# %% [markdown]
# <h1 id="types_objects" align="center">Sharon Raja S</h1>

# %% [markdown]
# <h2 id="types_objects" align="center">My Project 2</h2>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h2 id="types_objects" align="center">Scatter Plot</h2>
# <h3 id="types_objects" align="center">Scatter Plot using a list or a table</h3>

# %%
x=[1,2,3,4,5,6]
y=[10,50,100,80,60,90]

plt.scatter(x,y)
plt.show()

# %%
plt.scatter([1,2,3,4,5],[100,200,300,400,500])
plt.show()

# %% [markdown]
# ### scatter plot using numpy

# %%
xpts=np.array([0,4])
ypts=np.array([0,100])

plt.scatter(xpts,ypts)
plt.show()

# %% [markdown]
# #### colour

# %%
x=[1,2,3,4,5,6]
y=[10,50,100,80,60,90]

plt.scatter(x,y,color="red")
plt.show()

# %% [markdown]
# #### size

# %%
plt.scatter(x,y,color="green",s=90)
plt.show()

# %% [markdown]
# #### alpha=> transparancy

# %%
plt.scatter(x,y,color="red",s=100,alpha=0.5)
plt.show()

# %% [markdown]
# #### markers

# %%
plt.scatter(x,y,color="red",s=200,alpha=0.6,marker="*")
plt.show()

# %% [markdown]
# #### edge color

# %%
plt.scatter(x,y,color="violet",s=200,alpha=0.6,marker="*",edgecolors="g")
plt.show()

# %% [markdown]
# #### edge line width

# %%
plt.scatter(x,y,color="violet",s=200,alpha=0.7,marker="*",edgecolors="b",linewidths=2)
plt.show()

# %% [markdown]
# ### colorful scatter plot

# %% [markdown]
# #### colour scheme

# %%
color=["red","green","blue","violet","brown","orange"]
plt.scatter(x,y,c=color)
plt.show()

# %% [markdown]
# #### size levels

# %%
color=["red","green","blue","violet","brown","orange"]
size=[10,100,20,90,200,70]
plt.scatter(x,y,c=color,s=size)
plt.show()

# %% [markdown]
# #### alpha levels

# %%
color=["red","green","blue","violet","brown","orange"]
size=[10,100,20,90,200,70]
al=[0.2,0.4,0.1,0.8,0.10,0.7]
plt.scatter(x,y,c=color,s=size,alpha=al)
plt.show()

# %% [markdown]
# #### color bar for color map

# %%
color=["red","green","blue","violet","brown","orange"]
col=[200,100,300,700,500,400]
size=[10,100,20,90,50,70]
plt.scatter(x,y,c=col,s=size,alpha=0.7,cmap="viridis")
plt.colorbar()
plt.show()

# %% [markdown]
# #### to set name to color bar

# %%
color=["red","green","blue","violet","brown","orange"]
col=[200,100,300,700,500,400]
size=[10,100,20,90,50,70]
plt.scatter(x,y,c=col,s=size,alpha=0.7,cmap="viridis")
t=plt.colorbar()
t.set_label("ColorBar")
plt.show()

# %% [markdown]
# #### color bar, legend, title, x lable, y lable, legend lable

# %%
x=[1,2,3]
y=[10,50,100]
plt.scatter(x,y,color="black",label="Count")
plt.colorbar()
plt.legend()
plt.title("Scatter Plot")
plt.xlabel("Day")
plt.ylabel("No.")
plt.show()

# %% [markdown]
# ### scatter plot for square numbers

# %%
x=[0,1,2,3,4,5]
y=[i**2 for i in x]

plt.title('Simple scatter plot')
plt.xlabel('X-Axis')
plt.ylabel('X-Squares')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### using np array

# %%
x=np.arange(0,10,2)
y=[i**2 for i in x]

plt.title('Simple Scatter plot')
plt.xlabel('X-Axis')
plt.ylabel('X-Squares')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ### with markers and styles for square numbers

# %%
x=np.arange(0,10,2)
y=x**2

plt.title('Simple Scatter plot')
plt.xlabel('X-Axis')
plt.ylabel('X-Squares')
plt.scatter(x,y,marker=".",s=50,c='y',edgecolors='k')
plt.show()

# %% [markdown]
# ### my push-ups

# %%
days=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday']
numbers=[25,15,20,10,18,30,20]

plt.scatter(days,numbers)
plt.title('My Push-ups Graph')
plt.xlabel('Days')
plt.ylabel('Number of Push-ups')
plt.show()

# %% [markdown]
# ### x limit, y limit
# #### Velocity m/s

# %%
x=[0,5,10,15,20,25,30]
y1=[10,15,20,20,30,15,0]
y2=[10,12,15,12,20,10,0]
plt.scatter(x,y1,label='line-1')
plt.scatter(x,y2,label='line-2')

plt.title('Velocity-Time')
plt.xlabel("Velocity m/s")
plt.ylabel('Time(s)')
plt.xlim(0,32)
plt.ylim(0,35)
plt.legend()
plt.show()

# %% [markdown]
# ### Scatter plot of Mark comparion

# %%
subjects=['Tamil','English','Maths','Biology','Chemistry','Physics','Computer']
Raju=[87,82,78,73,66,75,85]
Bala=[80,70,61,78,83,87,82]
Gopi=[86,72,63,71,82,78,92]

plt.scatter(subjects,Raju,label='Raju',marker='o',color='g',edgecolors="y",linewidths=1)
plt.scatter(subjects,Bala,label='Bala',marker='o',color='r',edgecolors="y",linewidths=1)
plt.scatter(subjects,Gopi,label='Gopi',marker='o',color='b',edgecolors="y",linewidths=1)

plt.legend()
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Marks Comparison')
plt.show()

# %% [markdown]
# #### 2022 & 2023

# %%
x=[1,2,3,4,5,6]

y=[10,50,100,80,60,90]
size=[10,100,20,90,50,70]
plt.scatter(x,y,s=size,alpha=1,color="yellow",label="2022")

y=[100,70,10,50,30,20]
size=[70,50,90,20,100,10]
plt.scatter(x,y,s=size,alpha=1,color="green",label="2023")

plt.legend()
plt.title("Scatter Plot",fontsize=10)
plt.show()

# %% [markdown]
# ### Previous 5 years & Present year record

# %% [markdown]
# #### 2018-2023

# %%
x=[1,2,3,4,5,6]

# %%
# 2018
y=[50,20,60,40,50,70]
size=[20,90,30,40,50,60]
plt.scatter(x,y,s=size,alpha=1,color="red",label="2018")

# 2019
y=[60,90,80,30,40,30]
size=[10,100,20,90,40,70]
plt.scatter(x,y,s=size,alpha=1,color="orange",label="2019")

# 2020
y=[40,30,50,20,90,60]
size=[90,80,10,20,30,50]
plt.scatter(x,y,s=size,alpha=1,color="yellow",label="2020")

# 2021
y=[10,50,100,80,60,90]
size=[10,100,20,90,50,70]
plt.scatter(x,y,s=size,alpha=1,color="yellowgreen",label="2021")

# 2022
y=[30,40,70,60,70,80]
size=[10,100,20,90,50,70]
plt.scatter(x,y,s=size,alpha=1,color="green",label="2022")

# 2023
y=[100,70,10,50,30,20]
size=[50,100,60,90,80,70]
plt.scatter(x,y,s=size,alpha=1,color="green",label="2023",marker="*",edgecolors="b",linewidths=1)

plt.legend()
plt.title("Yearly Growth",fontsize=20)
plt.xlabel("Day",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# <h3 id="types_objects" align="center">Scatter Plot using Equations</h3>

# %% [markdown]
# ### 1
# #### y=2x+3y, y=2y-x

# %%
x=np.arange(1,11,1)
y=np.arange(2,30,3)
y1=(2*x)+(3*y)
y2=(2*y)-x

plt.scatter(x,y1,color='b',label='y=2x+3y')
plt.scatter(x,y2,color='r',label='y=2y-x')
plt.legend()
plt.show()

# %% [markdown]
# ### 2
# #### y=2x+1, y=2x^2+2

# %%
x=np.arange(1,11,1)
y=np.arange(2,30,3)
y1=(2*x)+1
y2=(2*x*x)+2

plt.scatter(x,y1,color='g',label='y=2x+1')
plt.scatter(x,y2,color='r',label='y=2x^2+2')
plt.legend()
plt.show()
