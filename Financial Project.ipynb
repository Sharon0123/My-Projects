# %% [markdown]
# <h1 id="types_objects" align="center">Sharon Raja S</h1>

# %% [markdown]
# <h2 id="types_objects" align="center">My Project 5</h2>

# %% [markdown]
# <h3 id="types_objects" align="center">Financial Analysis</h3>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
#data=pd.read_csv('Financial Sample.csv')
#data.head()
#os.chdir(r'My Projects')
finance=pd.read_csv('Financial Sample.csv')
print(finance.columns)
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
sal=finance['Sales'][:5]
sal.astype('int')
print(finance['Date'][:5])
sa=finance.Sales.astype(int)
print(sal)
mon=finance['Month Name'][:5]
print(mon)
yea=finance['Year'][:5]
print(yea)
# Out:
# 0    2014-01-01
# 1    2014-01-01
# 2    2014-06-01
# 3    2014-06-01
# 4    2014-06-01
# Name: Date, dtype: object
# 0    32370.0
# 1    26420.0
# 2    32670.0
# 3    13320.0
# 4    37050.0
# Name: Sales, dtype: float64
# 0    January
# 1    January
# 2       June
# 3       June
# 4       June
# Name: Month Name, dtype: object
# 0    2014
# 1    2014
# 2    2014
# 3    2014
# 4    2014
# Name: Year, dtype: int64

# %%
print(finance["Sales"][:3].tolist())
# Out:
# [32370.0, 26420.0, 32670.0]

# %% [markdown]
# ### Sales by Month

# %%
s=finance["Sales"][:50].tolist()
m=finance['Month Name'][:50].tolist()
y=finance['Year'][:50].astype('str')
y1=y.tolist()

plt.figure(figsize=(9,7))
#plt.ylim(0,1000000)
plt.plot(m,s)
plt.scatter(m,s)
plt.plot(y1,s)
plt.scatter(y1,s)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(9,7))
plt.bar(m,s)
plt.bar(y1,s)
plt.xticks(rotation=90)
plt.show()

# %%
sal=finance['Sales'][:50]
mon=finance['Month Name'][:50]
mon1=mon.sort_values()
yea=finance['Year'][:50]

# %% [markdown]
# ### line plot

# %%
z=yea.astype('str')
x1=finance['Month Name']
x2=finance['Year']
y=finance['Sales']

# %%
plt.figure(figsize=(9,7))
#plt.ylim(0,1000000)
plt.plot(mon1,sal,label='Month')
plt.plot(z,sal,label='Year')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# ### scatter plot

# %%
plt.figure(figsize=(9,7))
plt.scatter(mon,sal,label='Month')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### bar chart

# %%
plt.figure(figsize=(9,7))
plt.bar(mon,sal,label='Month')
plt.xticks(rotation=90)
#plt.bar(z,sal,label='Year')
plt.show()

# %% [markdown]
# ### multi plot

# %%
plt.figure(figsize=(9,7))
plt.bar(mon1,sal,label='Month')
plt.scatter(mon1,sal,label='Month')
plt.plot(mon1,sal,label='Month',color='r')
plt.xticks(rotation=90)
plt.show()

# %%
yea=finance['Year']#[:50]
sale=finance['Sales']#[:50]
z1=yea.astype('str')
plt.scatter(z1,sale,label='Year')
plt.show()

# %%
plt.bar(z1,sale,label='Year')
plt.show()

# %%
seg=finance['Segment']
con=finance['Country']
pro=finance['Product']
disban=finance['Discount Band']

# %%
plt.figure(figsize=(9,7))
plt.scatter(seg,con)
plt.show()

# %%
plt.figure(figsize=(11,7))
plt.bar(seg,con)
plt.show()
